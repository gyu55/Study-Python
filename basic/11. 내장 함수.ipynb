# %%
# 65 -> "A"
chr(65)

# "A" -> 65
ord("A")
# Out:
# 65

# %%
password = "test123"

for i in password:
    print(chr(ord(i) * 5000), end="")
# Out:
# 򍦠񻒨򌘘򍦠𻴈𽂐𾐘

# %%
expression = input("수식을 입력하세요.\nex)10+10\n")
# Out:
# 수식을 입력하세요.
# ex)10+10
#  150 * 30

# %%
eval(expression)
# Out:
# 4500

# %%
print(format(1000000, ","))
# _로 표기하면 형변환을 하지 않고 자릿수 표현이 가능하기 때문에 _ 사용 권장 -> int유지 가능 , 사용하면 str으로 됨.
print(format(1000000, "_"))
print(type(format(1000000, ",")))
# Out:
# 1,000,000
# <class 'str'>

# %%
# 반환값 튜플
divmod(10, 2)
# Out:
# (5, 0)

# %%
# 오사오입
# 값이 1 ~ 4까지일 때 버림
# 값이 5일 때 -> 앞 자리가 홀수면 반올림 / 앞 자리가 짝수면 버림
print(round(1.5))
print(round(2.5))
print(round(3.5))
print(round(4.5))
# Out:
# 2
# 2
# 4
# 4

# %% [markdown]
# ### 문자열 함수

# %%
# count
print(count

# %%
# find
print("asdawesgbdvdse".find("e"))
# Out:
# 5

# %%
# 마지막 e의 인덱스 번호
print("asjudneaiucnauw".rfind("e"))
# Out:
# 6

# %%
print("a".upper())
print("A".lower())
# Out:
# A
# a

# %%
# 파스칼 표기법
"apple".capitalize()
# Out:
# 'Apple'

# %%
print("a".join("b"))
# Out:
# b

# %%
li4 = [str((i + 1) * 10) for i in range(5)]
li4
# Out:
# ['10', '20', '30', '40', '50']

# %%
"".join(li4)
# Out:
# '1020304050'

# %%
str1 = "Life is to short"

# %%
# 2. 값이 바뀌면 새롭게 반환
# 원본이 바뀌진 않고 새로운 문자열을 리턴함
str1.replace("short", "Long")
# Out:
# 'Life is to Long'

# %%
str1
# Out:
# 'Life is to short'

# %%
# 문자열 내부의 값이 정수로만 이루어져있는지 확인 -> bool type
"10".isdigit()
# Out:
# True

# %%
"10r".isdigit()
# Out:
# False

# %%
num1 = input("정수를 입력하세요.")
# Out:
# 정수를 입력하세요. 정수

# %%
if num1.isdigit():
    num1 = int(num1)
else:
    print("정신 차려!")
# Out:
# 정신 차려!

# %%
# 문자가 포함되었는지 확인하는 메서드
num1.isalpha()
# Out:
# True

# %%
data3 = "******da****************da**"

# %%
print(data3.replace("*", ""))
# Out:
# dada

# %%
data3[data3.find("d"):]
# Out:
# 'da****************da**'

# %%
# 왼쪽 다 지우기
print(data3.lstrip("*"))
# 오른쪽 다 지우기
print(data3.rstrip("*"))
# 양쪽 다 지우기
print(data3.strip("*"))
# Out:
# da****************da**
# ******da****************da
# da****************da

# %%
"2131.23.23.12413523.42141".split(".")
# Out:
# ['2131', '23', '23', '12413523', '42141']

# %%
names = "짱구", "하영", "수지"
score = 20, 40, 60
address = "떡잎마을", "강남", "압구정"

# %%
for i in zip(names, score, address):
    print(i)
# Out:
# ('짱구', 20, '떡잎마을')
# ('하영', 40, '강남')
# ('수지', 60, '압구정')
