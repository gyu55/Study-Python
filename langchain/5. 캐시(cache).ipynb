# %%
from dotenv import load_dotenv
import os

load_dotenv()
print(os.environ.get('OPENAI_API_KEY')[:20])

# v1.2.6
from langchain_openai.chat_models import ChatOpenAI
from langchain_core.globals import set_llm_cache
from langchain_core.caches import InMemoryCache
# Out:
# sk-proj-_fMUdLs8U_td

# %%
# 모든 llm의 response가 메모리에 저장됨
in_memory_cache = InMemoryCache()
set_llm_cache(in_memory_cache)

# %%
chat = ChatOpenAI()

# %%
import time
from datetime import timedelta

# %%
def check_laptime(message):
    start_time = time.time()
    response = chat.invoke(message)
    end_time = time.time()
    elapsed_time = end_time - start_time
    
    print(f"경과 시간: {str(timedelta(seconds=elapsed_time))}")
    print(f"글자 수: {len(response.content)}")
    print(response.content)

# %%
check_laptime("피자를 만드는 방법에 대해서 알려줘!")
# Out:
# 경과 시간: 0:00:05.829857
# 글자 수: 487
# 피자를 만드는 방법은 다음과 같습니다:
#
# 1. 반죽 만들기: 밀가루, 물, 이스트, 소금, 설탕을 섞어 탄력 있는 반죽을 만듭니다. 반죽을 만드는데 시간이 걸리므로 미리 만들어 두는 것이 좋습니다.
#
# 2. 피자 도우 만들기: 반죽을 펴고 동그랗게 뻗어서 도우를 만듭니다. 피자 팬에 도우를 올려 펴줍니다.
#
# 3. 소스 만들기: 토마토 소스나 크림소스 등을 도우 위에 발라줍니다.
#
# 4. 토핑 올리기: 피자에 원하는 토핑들을 올려줍니다. 새우, 햄, 피망, 올리브, 양파 등 다양한 재료를 사용할 수 있습니다.
#
# 5. 오븐에 구워주기: 200°C로 예열된 오븐에 피자를 넣고 15-20분 정도 구워줍니다. 피자가 바삭하고 노릇노릇해질 때까지 구워주세요.
#
# 6. 완성: 구워진 피자를 꺼내어 잘라내어서 완성된 피자를 즐기면 됩니다. 견과류나 파슬리, 파마산 치즈를 뿌려 감칠맛을 더할 수도 있습니다.
#
# 이렇게하면 집에서 맛있는 피자를 만들 수 있습니다!Bon Appetit!

# %%
print(in_memory_cache._cache)
# Out:
# {('[{"lc": 1, "type": "constructor", "id": ["langchain", "schema", "messages", "HumanMessage"], "kwargs": {"content": "\\ud53c\\uc790\\ub97c \\ub9cc\\ub4dc\\ub294 \\ubc29\\ubc95\\uc5d0 \\ub300\\ud574\\uc11c \\uc54c\\ub824\\uc918!", "type": "human"}}]', '{"id": ["langchain", "chat_models", "openai", "ChatOpenAI"], "kwargs": {"model_name": "gpt-3.5-turbo", "openai_api_key": {"id": ["OPENAI_API_KEY"], "lc": 1, "type": "secret"}, "openai_proxy": null, "output_version": null, "stream_usage": true}, "lc": 1, "name": "ChatOpenAI", "type": "constructor"}---[(\'stop\', None)]'): [ChatGeneration(text='피자를 만드는 방법은 다음과 같습니다:\n\n1. 반죽 만들기: 밀가루, 물, 이스트, 소금, 설탕을 섞어 탄력 있는 반죽을 만듭니다. 반죽을 만드는데 시간이 걸리므로 미리 만들어 두는 것이 좋습니다.\n\n2. 피자 도우 만들기: 반죽을 펴고 동그랗게 뻗어서 도우를 만듭니다. 피자 팬에 도우를 올려 펴줍니다.\n\n3. 소스 만들기: 토마토 소스나 크림소스 등을 도우 위에 발라줍니다.\n\n4. 토핑 올리기: 피자에 원하는 토핑들을 올려줍니다. 새우, 햄, 피망, 올리브, 양파 등 다양한 재료를 사용할 수 있습니다.\n\n5. 오븐에 구워주기: 200°C로 예열된 오븐에 피자를 넣고 15-20분 정도 구워줍니다. 피자가 바삭하고 노릇노릇해질 때까지 구워주세요.\n\n6. 완성: 구워진 피자를 꺼내어 잘라내어서 완성된 피자를 즐기면 됩니다. 견과류나 파슬리, 파마산 치즈를 뿌려 감칠맛을 더할 수도 있습니다.\n\n이렇게하면 집에서 맛있는 피자를 만들 수 있습니다!Bon Appetit!', generation_info={'finish_reason': 'stop', 'logprobs': None}, message=AIMessage(content='피자를 만드는 방법은 다음과 같습니다:\n\n1. 반죽 만들기: 밀가루, 물, 이스트, 소금, 설탕을 섞어 탄력 있는 반죽을 만듭니다. 반죽을 만드는데 시간이 걸리므로 미리 만들어 두는 것이 좋습니다.\n\n2. 피자 도우 만들기: 반죽을 펴고 동그랗게 뻗어서 도우를 만듭니다. 피자 팬에 도우를 올려 펴줍니다.\n\n3. 소스 만들기: 토마토 소스나 크림소스 등을 도우 위에 발라줍니다.\n\n4. 토핑 올리기: 피자에 원하는 토핑들을 올려줍니다. 새우, 햄, 피망, 올리브, 양파 등 다양한 재료를 사용할 수 있습니다.\n\n5. 오븐에 구워주기: 200°C로 예열된 오븐에 피자를 넣고 15-20분 정도 구워줍니다. 피자가 바삭하고 노릇노릇해질 때까지 구워주세요.\n\n6. 완성: 구워진 피자를 꺼내어 잘라내어서 완성된 피자를 즐기면 됩니다. 견과류나 파슬리, 파마산 치즈를 뿌려 감칠맛을 더할 수도 있습니다.\n\n이렇게하면 집에서 맛있는 피자를 만들 수 있습니다!Bon Appetit!', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 470, 'prompt_tokens': 28, 'total_tokens': 498, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-3.5-turbo-0125', 'system_fingerprint': None, 'id': 'chatcmpl-DfIi8ensPe41iMA3R9hryYZxUMvd0', 'service_tier': 'default', 'finish_reason': 'stop', 'logprobs': None}, id='lc_run--019e24e9-82e3-7e93-b615-68a53d70f7c6-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 28, 'output_tokens': 470, 'total_tokens': 498, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}}))]}

# %%
for i in in_memory_cache._cache.keys():
    print(i)
# Out:
# ('[{"lc": 1, "type": "constructor", "id": ["langchain", "schema", "messages", "HumanMessage"], "kwargs": {"content": "\\ud53c\\uc790\\ub97c \\ub9cc\\ub4dc\\ub294 \\ubc29\\ubc95\\uc5d0 \\ub300\\ud574\\uc11c \\uc54c\\ub824\\uc918!", "type": "human"}}]', '{"id": ["langchain", "chat_models", "openai", "ChatOpenAI"], "kwargs": {"model_name": "gpt-3.5-turbo", "openai_api_key": {"id": ["OPENAI_API_KEY"], "lc": 1, "type": "secret"}, "openai_proxy": null, "output_version": null, "stream_usage": true}, "lc": 1, "name": "ChatOpenAI", "type": "constructor"}---[(\'stop\', None)]')

# %%
for i in in_memory_cache._cache.values():
    print(i)
# Out:
# [ChatGeneration(text='피자를 만드는 방법은 다음과 같습니다:\n\n1. 반죽 만들기: 밀가루, 물, 이스트, 소금, 설탕을 섞어 탄력 있는 반죽을 만듭니다. 반죽을 만드는데 시간이 걸리므로 미리 만들어 두는 것이 좋습니다.\n\n2. 피자 도우 만들기: 반죽을 펴고 동그랗게 뻗어서 도우를 만듭니다. 피자 팬에 도우를 올려 펴줍니다.\n\n3. 소스 만들기: 토마토 소스나 크림소스 등을 도우 위에 발라줍니다.\n\n4. 토핑 올리기: 피자에 원하는 토핑들을 올려줍니다. 새우, 햄, 피망, 올리브, 양파 등 다양한 재료를 사용할 수 있습니다.\n\n5. 오븐에 구워주기: 200°C로 예열된 오븐에 피자를 넣고 15-20분 정도 구워줍니다. 피자가 바삭하고 노릇노릇해질 때까지 구워주세요.\n\n6. 완성: 구워진 피자를 꺼내어 잘라내어서 완성된 피자를 즐기면 됩니다. 견과류나 파슬리, 파마산 치즈를 뿌려 감칠맛을 더할 수도 있습니다.\n\n이렇게하면 집에서 맛있는 피자를 만들 수 있습니다!Bon Appetit!', generation_info={'finish_reason': 'stop', 'logprobs': None}, message=AIMessage(content='피자를 만드는 방법은 다음과 같습니다:\n\n1. 반죽 만들기: 밀가루, 물, 이스트, 소금, 설탕을 섞어 탄력 있는 반죽을 만듭니다. 반죽을 만드는데 시간이 걸리므로 미리 만들어 두는 것이 좋습니다.\n\n2. 피자 도우 만들기: 반죽을 펴고 동그랗게 뻗어서 도우를 만듭니다. 피자 팬에 도우를 올려 펴줍니다.\n\n3. 소스 만들기: 토마토 소스나 크림소스 등을 도우 위에 발라줍니다.\n\n4. 토핑 올리기: 피자에 원하는 토핑들을 올려줍니다. 새우, 햄, 피망, 올리브, 양파 등 다양한 재료를 사용할 수 있습니다.\n\n5. 오븐에 구워주기: 200°C로 예열된 오븐에 피자를 넣고 15-20분 정도 구워줍니다. 피자가 바삭하고 노릇노릇해질 때까지 구워주세요.\n\n6. 완성: 구워진 피자를 꺼내어 잘라내어서 완성된 피자를 즐기면 됩니다. 견과류나 파슬리, 파마산 치즈를 뿌려 감칠맛을 더할 수도 있습니다.\n\n이렇게하면 집에서 맛있는 피자를 만들 수 있습니다!Bon Appetit!', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 470, 'prompt_tokens': 28, 'total_tokens': 498, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-3.5-turbo-0125', 'system_fingerprint': None, 'id': 'chatcmpl-DfIi8ensPe41iMA3R9hryYZxUMvd0', 'service_tier': 'default', 'finish_reason': 'stop', 'logprobs': None}, id='lc_run--019e24e9-82e3-7e93-b615-68a53d70f7c6-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 28, 'output_tokens': 470, 'total_tokens': 498, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}}))]

# %%
# 프로그램 종료 시 삭제 자동 삭제
# 캐시 삭제
in_memory_cache.clear()

# %%
in_memory_cache._cache
# Out:
# {}

# %% [markdown]
# ## 디버그 설정

# %%
from langchain_core.globals import set_debug

# %%
set_debug(True)

# %%
chat.invoke("랍스터는 누구의 후손이니?")
# Out:
# [llm/start] [llm:ChatOpenAI] Entering LLM run with input:
# {
#   "prompts": [
#     "Human: 랍스터는 누구의 후손이니?"
#   ]
# }
# [llm/end] [llm:ChatOpenAI] [1.49s] Exiting LLM run with output:
# {
#   "generations": [
#     [
#       {
#         "text": "랍스터의 후손은 새우와 게와 같은 크러스트세계의 족류들 중 하나이다.",
#         "generation_info": {
#           "finish_reason": "stop",
#           "logprobs": null
#         },
#         "type": "ChatGeneration",
#         "message": {
#           "lc": 1,
#           "type": "constructor",
#           "id": [
#             "langchain",
#             "schema",
#             "messages",
#             "AIMessage"
#           ],
#           "kwargs": {
#             "content": "랍스터의 후손은 새우와 게와 같은 크러스트세계의 족류들 중 하나이다.",
#             "additional_kwargs": {
#               "refusal": null
#             },
#             "response_metadata": {
#               "token_usage": {
#                 "completion_tokens": 37,
#                 "prompt_tokens": 23,
#                 "total_tokens": 60,
#                 "completion_tokens_details": {
#                   "accepted_prediction_tokens": 0,
#                   "audio_tokens": 0,
#                   "reasoning_tokens": 0,
#                   "rejected_prediction_tokens": 0
#                 },
#                 "prompt_tokens_details": {
#                   "audio_tokens": 0,
#                   "cached_tokens": 0
#                 }
#               },
#               "model_provider": "openai",
#               "model_name": "gpt-3.5-turbo-0125",
#               "system_fingerprint": null,
#               "id": "chatcmpl-DfIou4BOnubF9hnTlfb3kjFCWtPTg",
#               "service_tier": "default",
#               "finish_reason": "stop",
#               "logprobs": null
#             },
#             "type": "ai",
#             "id": "lc_run--019e24ef-ea06-7581-b83f-0917076e5e4f-0",
#             "usage_metadata": {
#               "input_tokens": 23,
#               "output_tokens": 37,
#               "total_tokens": 60,
#               "input_token_details": {
#                 "audio": 0,
#                 "cache_read": 0
#               },
#               "output_token_details": {
#                 "audio": 0,
#                 "reasoning": 0
#               }
#             },
#             "tool_calls": [],
#             "invalid_tool_calls": []
#           }
#         }
#       }
#     ]
#   ],
#   "llm_output": {
#     "token_usage": {
#       "completion_tokens": 37,
#       "prompt_tokens": 23,
#       "total_tokens": 60,
#       "completion_tokens_details": {
#         "accepted_prediction_tokens": 0,
#         "audio_tokens": 0,
#         "reasoning_tokens": 0,
#         "rejected_prediction_tokens": 0
#       },
#       "prompt_tokens_details": {
#         "audio_tokens": 0,
#         "cached_tokens": 0
#       }
#     },
#     "model_provider": "openai",
#     "model_name": "gpt-3.5-turbo-0125",
#     "system_fingerprint": null,
#     "id": "chatcmpl-DfIou4BOnubF9hnTlfb3kjFCWtPTg",
#     "service_tier": "default"
#   },
#   "run": null,
#   "type": "LLMResult"
# }
# AIMessage(content='랍스터의 후손은 새우와 게와 같은 크러스트세계의 족류들 중 하나이다.', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 37, 'prompt_tokens': 23, 'total_tokens': 60, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-3.5-turbo-0125', 'system_fingerprint': None, 'id': 'chatcmpl-DfIou4BOnubF9hnTlfb3kjFCWtPTg', 'service_tier': 'default', 'finish_reason': 'stop', 'logprobs': None}, id='lc_run--019e24ef-ea06-7581-b83f-0917076e5e4f-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 23, 'output_tokens': 37, 'total_tokens': 60, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}})

# %%
set_debug(False)

# %%
set_llm_cache(None)
