# %% [markdown]
# # 프롬프트 저장, 불러오기

# %% [markdown]
# ## JSON

# %%
from dotenv import load_dotenv
import os

load_dotenv()
print(os.environ.get('OPENAI_API_KEY')[:20])
# Out:
# sk-proj-_fMUdLs8U_td

# %%
base_path = r"C:\back_0900_ngh\python\resource"

# %%
base_path
# Out:
# 'C:\\back_0900_ngh\\python\\resource'

# %%
file_path = os.path.join(base_path, "prompt.json")

# %%
file_path
# Out:
# 'C:\\back_0900_ngh\\python\\resource\\prompt.json'

# %%
with open(file_path, "w") as f:
    f.write("""
        {
            "_type": "prompt",
            "template": "{country}에 대해서 어떻게 알고 있어요?",
            "input_variables": ["country"]
        }
    """)

# %%
from langchain_openai.chat_models import ChatOpenAI
from langchain_core.prompts import load_prompt

# %%
chat = ChatOpenAI(temperature=0.1)

# %%
prompt = load_prompt(file_path)

# %%
chain = prompt | chat

# %%
result = chain.invoke({
    "country": "한국"
})

# %%
result.content
# Out:
# '한국은 동아시아에 위치한 나라로, 수도는 서울입니다. 한국은 역사적으로 중국과 일본의 영향을 받았으며, 한글이라는 고유의 문자를 사용합니다. 한국은 전통적인 문화와 현대적인 발전이 조화를 이루는 나라로, K-pop, K-drama, 한식 음식 등이 전 세계적으로 인기를 끌고 있습니다. 또한 한국은 세계적으로 유명한 기업들이 많이 발달한 나라로, 기술력과 경제력이 뛰어나다고 알려져 있습니다. 한국은 또한 아름다운 자연경관과 역사적인 유적지들이 많이 있어 관광객들에게 인기 있는 여행지입니다.'

# %% [markdown]
# ## YAML 파일

# %%
file_path = os.path.join(base_path, "prompt.yaml")

# %%
file_path
# Out:
# 'C:\\back_0900_ngh\\python\\resource\\prompt.yaml'

# %%
from langchain_openai.chat_models import ChatOpenAI
from langchain_core.prompts import load_prompt

# %%
with open(file_path, "w") as f:
    f.write("""
"_type": "prompt"
"template": "{country}에서 가장 유명한 음식이 어떤 건가요?"
"input_variables": ["country"]
    """)

# %%
load_prompt(file_path)
# Out:
# PromptTemplate(input_variables=['country'], input_types={}, partial_variables={}, template='{country}에서 가장 유명한 음식이 어떤 건가요?')

# %%
prompt = load_prompt(file_path)

# %%
prompt.format(country="일본")
# Out:
# '일본에서 가장 유명한 음식이 어떤 건가요?'

# %%
chain = prompt | chat

# %%
result = chain.invoke({
    "country": "일본"
})

# %%
print(result.content)
# Out:
# 일본에서 가장 유명한 음식 중 일부는 다음과 같습니다:
#
# 1. 스시: 신선한 회와 식초로 맛을 낸 쌀밥으로 만든 일본 전통 음식
# 2. 라멘: 면과 스프, 고기 등을 넣은 일본의 대표적인 면 요리
# 3. 우동: 면과 국물, 다양한 재료를 넣어 만든 일본의 전통 면 요리
# 4. 텐동: 새우, 채소 등을 튀긴 후 덮밥 위에 올려 먹는 일본의 전통 음식
# 5. 가츠동: 돼지고기, 닭고기 등을 튀긴 후 덮밥 위에 올려 먹는 일본의 전통 음식
#
# 이 외에도 일본에는 다양한 지방별 전통 음식들이 있으며, 각 지역마다 특색 있는 음식들이 존재합니다.
